# %%
import googleapiclient.discovery
import pandas as pd

# %%
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyADyp0cwIbQM2Di0lwd3p27jVdfL8Kgb08"

# %%
from types import resolve_bases
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)
request = youtube.commentThreads().list(part="snippet",videoId="DjR3R1iV1oI",maxResults=100)
response = request.execute()

# %%
comments = []

for item in response['items']:
  comment = item['snippet']['topLevelComment']['snippet']

  comments.append([

  comment['authorDisplayName'],

  comment['publishedAt'],

  comment['updatedAt'],

  comment['likeCount'],

  comment['textDisplay']

  ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

# %%
df
# Out:
#                      author          published_at            updated_at  \
# 0        @kashishkumari6443  2024-07-19T07:30:33Z  2024-07-19T07:30:33Z
# 1               @Temp-nu4kw  2024-07-19T07:22:49Z  2024-07-19T07:22:49Z
# 2                 @rajdarji  2024-07-19T07:21:39Z  2024-07-19T07:21:39Z
# 3         @rincykapatel4235  2024-07-19T07:20:55Z  2024-07-19T07:20:55Z
# 4  @karnavsonavanesvlog8303  2024-07-19T07:20:00Z  2024-07-19T07:20:00Z
# 5                 @drdr3417  2024-07-19T07:19:38Z  2024-07-19T07:19:38Z
# 6          @ragulmarley4900  2024-01-18T08:02:45Z  2024-01-18T08:02:45Z
# 7                 @mraj1985  2024-01-11T09:28:05Z  2024-01-11T09:28:05Z
# 8                  @asp4628  2024-01-11T08:23:50Z  2024-01-11T08:23:50Z
#
#    like_count                                               text
# 0           0        Nice explanation! need more such projects .
# 1           0                                             Nice 👍
# 2           0          Can you please make a job ready course? 🙏
# 3           0        Can you please make more videos like this👆🤗
# 4           0                              Nice Explaination Sir
# 5           0                   Well Explained DAX Function Sir!
# 6           0  Please share data set useful to practice along...
# 7           0                     Way of explanation amazing sir
# 8           0             Do more real world projects end to end
